# %% [markdown]
# # Description
# This notebook serves a part of the pre-processing, mostly filtering charters by language and date.

# %% [markdown]
# # Imports and settings

# %%
import pandas as pd
import numpy as np
from transformers import pipeline
from datetime import datetime
import langid

# %%
from formutils import *

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# # Filter by given metadata
# ❗DISCLAIMER❗
# Full Monasterium.net data is not provided; instead, skip here and continue at "Filter by enriched metadata"

# %%
df = pd.read_json("../data/0-base/all-charters-mom.json")

# %% [markdown]
# Explode nested lists, check lengths

# %%
df_prep = explode_columns(
    df, ["cei_date_ATTRIBUTE_value", "cei_dateRange_ATTRIBUTE_from", "cei_dateRange_ATTRIBUTE_to"]
)
has_same_length(df_prep, df)
# Out:
# True

# %% [markdown]
# Sort, drop duplicates

# %%
sorted = df_prep.sort_values(by="atom_id", key=lambda x: x.str.len())
nodupl = sorted.drop_duplicates(subset="cei_tenor_joined", keep="last")

# %% [markdown]
# Filter by tenor length, arbitrary anti-clutter threshold

# %%
with_tenor = nodupl[nodupl["cei_tenor_joined"].astype(str).str.len() >= 10]

# %% [markdown]
# Align dates; using workaround filter for Monasterium.net's charter dating convention

# %%
def get_cei_date_value(row):
    date = row["cei_date_ATTRIBUTE_value"]
    date_bot = row["cei_dateRange_ATTRIBUTE_from"]
    date_top = row["cei_dateRange_ATTRIBUTE_to"]
    value = next((d for d in (date, date_bot, date_top) if pd.notna(d)), None)
    return value


def is_valid_date(date_value):
    return isinstance(date_value, str) and ("9999" not in date_value and "010101" not in date_value)

# %%
df_prep_applied = with_tenor.copy()
df_prep_applied["date_joined"] = df_prep_applied.apply(get_cei_date_value, axis=1)
df_prep_filtered = df_prep_applied.loc[df_prep_applied["date_joined"].apply(is_valid_date)]

# %% [markdown]
# Filter by date

# %%
df_prep_filtered_mhg = df_prep_filtered[(df_prep_filtered["date_joined"] <= "14000000") &
                                        (df_prep_filtered["date_joined"] >= "11000000")]
len(df_prep_filtered_mhg)
# Out:
# 21776

# %% [markdown]
# Filter by language

# %%
# Find existing languages
df_prep_filtered_mhg_exploded = explode_columns(df_prep_filtered_mhg, ["cei_lang_MOM"])
df_prep_filtered_mhg_exploded.cei_lang_MOM.value_counts().to_frame().sort_values(by="cei_lang_MOM", ascending=False)
# Out:
#                                                     cei_lang_MOM
# Deutsch                                                     9232
# Latein                                                      5905
# lat.                                                         168
# latinsky                                                      38
# dt.                                                           21
# Altserbisch.                                                  11
# Niederdeutsch                                                 11
# Ndt.                                                           9
# j. łaciński                                                    7
# nemški                                                         6
# lateinisch                                                     5
# Deutsch/Latein                                                 4
# Deutsch, Latein                                                3
# Serbisch                                                       2
# lat.                                                           2
# latein.                                                        2
# (des Originales:) Latein; (der Übersetzung:) De...             1
# Aus einem Copialbuche des Klosters Baumgartenbe...             1
# latinščina                                                     1
# nemščina                                                       1
# Latin                                                          1
# (des Originales:) Latein, (der Übersetzung:) De...             1
# (der Abschrift:) Deutsch                                       1
# Latein; Unterschrift Altserbisch.                              1
# Die Abschrift vom 18. Jh gibt den Text in der z...             1
# Deutsch, nur die Beglaubigung durch Notar Mutti...             1
# Latein; Deutsch                                                1
# Lat.                                                           1
# německy                                                        1
# deutsch                                                        1
# mittelniederdeutsch                                            1
# niederdeutsch                                                  1
# Latein/Ndt.                                                    1
# lat                                                            1
# latinský                                                       1
# latino                                                         1
# Latein+Deutsch                                                 1
# latein                                                         1
# Latein und Deutsch.                                            1
# (A) Latein. - (B) Deutsch.                                     1
# Altitalienisch.                                                1

# %%
# Select languages and filter
included_languages = [
    "Deutsch",
    "dt.",
    "deutsch",
    "nemški",
    "německy",
    "nemščina"
    ]

df_filtered = df_prep_filtered_mhg_exploded[df_prep_filtered_mhg_exploded["cei_lang_MOM"].isin(included_languages)]
len(df_filtered)
# Out:
# 9262

# %%
df_filtered.to_json(f"../data-push/0b-preprocessing-main/charters-filtered-simple.json")

# %% [markdown]
# # Filter by enriched metadata

# %% [markdown]
# Detect languages

# %%
df_filtered = pd.read_json(f"../data-push/0b-preprocessing-main/charters-filtered-simple.json")

# %%
# Load language detection model
model_checkpoint = "../models/mom-langdetect/langdetect_20221121"
pipe = pipeline("text-classification", model = model_checkpoint)

# %%
def get_detection_result(string):
    return pipe(str(string)[0:512])


def get_detection_label(detection_result):
    return detection_result[0]["label"]


def get_detection_score(detection_result):
    return detection_result[0]["score"]


def detect_language(row):
    lang_detect_result = get_detection_result(row["cei_tenor_joined"])
    row["language_label"] = get_detection_label(lang_detect_result)
    row["language_score"] = get_detection_score(lang_detect_result)
    return row

# %% [markdown]
# Detect and count language label and score

# %%
detected = df_filtered.progress_apply(detect_language, axis=1)
# Out:
#   0%|          | 0/9262 [00:00<?, ?it/s]

# %%
detected.language_label.value_counts()
# Out:
# fnhd    9191
# la        33
# ca        12
# sv         8
# cs         5
# pt         4
# de         2
# fi         2
# he         2
# mhd        1
# ro         1
# zh         1
# Name: language_label, dtype: int64

# %% [markdown]
# Filter by selected languages

# %%
include_languages = ["fnhd", "mhg"] #includes both, given that wrong classification is resolved by dating
filtered = detected[detected["language_label"].astype(str).str.contains("|".join(include_languages))]
filtered.to_json("../data-push/0b-preprocessing-main/charters-filtered-languages.json")

# %%
filtered = pd.read_json("../data-push/0b-preprocessing-main/charters-filtered-languages.json")

# %%
filtered.sort_values("language_score").iloc[0].cei_tenor_joined
# Out:
# 'Allen, die disen brief sehent oder horent lesen, kúnden wir Johans von Tengen, Walther von der Alten Klingen, Albrecht von Bussnang rittere, Lútolt von Arburg, || alle vier frij herren, Egbrecht von Goldenberg, Gotfrit von Húnaberg, Fridrich von Húnwile, Johans der Giel rittere, Johans Hofmeister von Frowenfeld senger || der stift des thůms ze Costentz, Johans vnd Růd. von Bonstetten gebrůdere, Peter von Ebersperg, Herrnan von Landenberg genant von Werdegg, Vlr. von || Aspermunt der elter, Růdolf von Goldenberg vnd Johans von Seon burger Zúrich vnd veriechen offenlich mit disem brief, als Růd. von Landenberg genant von Werdegg Griffense die burg die statt den se vnd die hofreiti mit lút, gúlt gůt vogteyen gericht twing vnd bann mit aller zů gehoret den edlen wolerbornen herren graf Fridrich, graf Tonat vnd graf Diethelm von Tokkenburg allen drin gebrůdern ze v´nser wegen recht vnd redlich ze koffen geben hat, als die kof brief wisent vnd sagent, die dar v´ber geben vnd besigelt sint, beschach das die vorgenanten herren von Tokkenburg oder ir erben, ob si enwerin, nu ald hie nach iemer bedorftin ald notdúrftig werin oder wurdin ze deheinen iren sachen von des vorgeschriben kofs wegen der briefen, die wir von dem edlen hern Peter von Hewen frij vnd ritter vnd von den fromen hern Herman von Landenberg ritter, pfaff Herman von Landenberg sinem brůder, Vlrich von Landenberg ir vetter, alle drij von Griffense, haben, das wir inen die vnuerzogenlich liehen súlent, als dik vnd als vil die vorgenanten herren von Tokkenburg vnd ir erben der selben briefen bedúrfent oder notdúrftig sint, bi den eiden, so wir von des vorgeschriben kofs wegen den selben herren von Tokkenburg gesworn haben, doch also das v´ns vnd v´nser erben die obgenanten herren von Tokkenburg vnd ir erben besorgen súlent, das v´ns die selben brief von inen wider geben vnd geantwúrt werdent in den eren, als wir si inen verliehen haben, ane alle geverd. Vnd her v´ber ze einem offenn vrkúnd so haben wir alle vnd v´nser ieklicher besunder sin eigen insigel offenlich gehenkt an disen brief. Der geben ist an sant Nyclaus abend, do man zalt von gottes gebúrt drúzechen hundert vnd sechzig jar, dar nach in dem núnden jare.'

# %% [markdown]
# Detect languages 2.0

# %% [markdown]
# This is done because chances are that the language model does not catch all latin charters due to its architecture

# %%
identifier = langid.langid.LanguageIdentifier.from_modelstring(langid.langid.model, norm_probs=True)

filtered["language_langid"] = None
filtered["confidence_langid"] = None

for item, row in tqdm(filtered.iterrows()):
    text = row["cei_tenor_joined"]
    language, confidence = identifier.classify(text)
    filtered.at[item, "language_langid"] = language
    filtered.at[item, "confidence_langid"] = confidence

filtered.language_langid.value_counts().keys().to_list()
# Out:
# 0it [00:00, ?it/s]
# ['de', 'lb', 'la', 'nl']

# %%
final_language_filtered = filtered[filtered["language_langid"] == "de"]

# %% [markdown]
# Check detection scores

# %%
final_language_filtered = filtered
final_language_filtered.sort_values("language_score", ascending=True)
# Out:
#                                                   atom_id  \
# 172016  [tag:www.monasterium.net,2011:/charter/CH-StiA...
# 184861  [tag:www.monasterium.net,2011:/charter/CSGVI/1...
# 184064  [tag:www.monasterium.net,2011:/charter/CSGV/1314]
# 173885  [tag:www.monasterium.net,2011:/charter/CH-StiA...
# 186703  [tag:www.monasterium.net,2011:/charter/CSGX/13...
# ...                                                   ...
# 186908  [tag:www.monasterium.net,2011:/charter/CSGX/13...
# 183726  [tag:www.monasterium.net,2011:/charter/CSGV/13...
# 183738  [tag:www.monasterium.net,2011:/charter/CSGV/13...
# 251841  [tag:www.monasterium.net,2011:/charter/DE-BayH...
# 123414  [tag:www.monasterium.net,2011:/charter/AT-StiA...
#
#                                       cei_abstract_joined  \
# 172016  Sechzehn Mitschuldner der Herren von Landenber...
# 184861  Peter von Diemberg und seine Verwandten verzic...
# 184064  Abt Heinrich von St. Gallen verleiht Eglolf vo...
# 173885  Ulrich Gamps von Kalcheren räumt dem Kloster S...
# 186703  Ulrich von Hardegg verleiht an Heinrich Salzma...
# ...                                                   ...
# 186908  Johann Midensun, Bürger zu St. Gallen, quittie...
# 183726  Meister und Pfleger des Spitals Lindau verpfli...
# 183738  Abt Heinrich von St. Gallen verpfändet an Hein...
# 251841  Probst Chunrat und der Convent zu Ranshofen ge...
# 123414  Rudolf der Wolfräuter stiftet zu St. Michael i...
#
#        cei_abstract_foreign  \
# 172016                   []
# 184861                   []
# 184064                   []
# 173885                   []
# 186703                   []
# ...                     ...
# 186908                   []
# 183726                   []
# 183738                   []
# 251841                   []
# 123414                   []
#
#                                          cei_tenor_joined cei_pTenor  \
# 172016  Allen, die disen brief sehent oder horent lese...         []
# 184861  Allen den, die disen brief an sehent lesent od...         []
# 184064  Item ain lehenbrieflin on ain sigel, wie herr ...         []
# 173885  Ich Vli Gamps von Kalcherren burger ze Veltkil...         []
# 186703  Ich Vllrich von Hardegg vergich offentlich für...         []
# ...                                                   ...        ...
# 186908  Allen den, die disen brief ansehent lesent ode...         []
# 183726  Wir ... der maister vnd die pfleger dez spital...         []
# 183738  Wir von gottis gnadin abt Heinrich von sante G...         []
# 251841  Wir Chunrat uon gotes gnaden propst ze Ranshou...         []
# 123414  Ich Rudolf der wolueroeuter vergich an disem b...         []
#
#        cei_placeName cei_lang_MOM cei_date        cei_dateRange  \
# 172016            []      Deutsch       []   [5. Dezember 1369]
# 184861            []      Deutsch       []  [1. September 1337]
# 184064            []      Deutsch       []               [1314]
# 173885            []      Deutsch       []    [4. Februar 1385]
# 186703            []      Deutsch       []      [21. Juni 1384]
# ...              ...          ...      ...                  ...
# 186908            []      Deutsch       []    [4. Oktober 1387]
# 183726            []      Deutsch       []  [25. November 1301]
# 183738  [St. Gallen]      Deutsch       []     [18. April 1302]
# 251841   [Ranshofen]      Deutsch       []    [28. Januar 1292]
# 123414            []      Deutsch       []    [13. August 1334]
#
#         cei_date_ATTRIBUTE_value  cei_dateRange_ATTRIBUTE_from  \
# 172016                       NaN                    13691205.0
# 184861                       NaN                    13370901.0
# 184064                       NaN                    13140101.0
# 173885                       NaN                    13850204.0
# 186703                       NaN                    13840621.0
# ...                          ...                           ...
# 186908                       NaN                    13871004.0
# 183726                       NaN                    13011125.0
# 183738                       NaN                    13020418.0
# 251841                       NaN                    12920128.0
# 123414                       NaN                    13340813.0
#
#         cei_dateRange_ATTRIBUTE_to  \
# 172016                  13691205.0
# 184861                  13370901.0
# 184064                  13141231.0
# 173885                  13850204.0
# 186703                  13840621.0
# ...                            ...
# 186908                  13871004.0
# 183726                  13011125.0
# 183738                  13020418.0
# 251841                  12920128.0
# 123414                  13340813.0
#
#                            cei_graphic_ATTRIBUTE_url_orig  \
# 172016  [StiASG_13691205_GG2-T6_v.jpg, StiASG_13691205...
# 184861                                                 []
# 184064                                                 []
# 173885  [StiASG_13850204_RR2-A3_v.jpg, StiASG_13850204...
# 186703                                                 []
# ...                                                   ...
# 186908                                                 []
# 183726                                                 []
# 183738                                                 []
# 251841                                                 []
# 123414  [K.._MOM-Bilddateien._~StFlorianjpgweb._~Urkun...
#
#        cei_graphic_ATTRIBUTE_url_copy  date_joined language_label  \
# 172016                             []     13691205           fnhd
# 184861                             []     13370901           fnhd
# 184064                             []     13140101           fnhd
# 173885                             []     13850204           fnhd
# 186703                             []     13840621           fnhd
# ...                               ...          ...            ...
# 186908                             []     13871004           fnhd
# 183726                             []     13011125           fnhd
# 183738                             []     13020418           fnhd
# 251841                             []     12920128           fnhd
# 123414                             []     13340813           fnhd
#
#         language_score language_langid confidence_langid
# 172016        0.521548              de               1.0
# 184861        0.595243              de               1.0
# 184064        0.818374              de               1.0
# 173885        0.832712              de               1.0
# 186703        0.888878              de               1.0
# ...                ...             ...               ...
# 186908        0.999971              de               1.0
# 183726        0.999971              de               1.0
# 183738        0.999971              de               1.0
# 251841        0.999971              de               1.0
# 123414        0.999971              de               1.0
#
# [9191 rows x 19 columns]

# %% [markdown]
# Sorting the charters by language_score suggests that practically all pieces have a score between 0.80 and 1, suggesting a high certainty regarding the classification.

# %%
final_language_filtered.sort_values("confidence_langid", ascending=True)
# Out:
#                                                   atom_id  \
# 218288  [tag:www.monasterium.net,2011:/charter/DE-AEK/...
# 168004  [tag:www.monasterium.net,2011:/charter/CH-StaA...
# 168953  [tag:www.monasterium.net,2011:/charter/CH-StaA...
# 185592  [tag:www.monasterium.net,2011:/charter/CSGVII/...
# 184906  [tag:www.monasterium.net,2011:/charter/CSGVI/1...
# ...                                                   ...
# 123359  [tag:www.monasterium.net,2011:/charter/AT-StiA...
# 123364  [tag:www.monasterium.net,2011:/charter/AT-StiA...
# 123366  [tag:www.monasterium.net,2011:/charter/AT-StiA...
# 123355  [tag:www.monasterium.net,2011:/charter/AT-StiA...
# 219177  [tag:www.monasterium.net,2011:/charter/DE-AKR/...
#
#                                       cei_abstract_joined  \
# 218288  Die Äbtissin Irmgard von Schoeneck verpachtet ...
# 168004  Eglolf von Rorschach beurkundet, dass bei der ...
# 168953  Johann von Bodman quittiert der Stadt St. Gall...
# 185592  Herzog Albrecht von Österreich verpflichtet si...
# 184906  Graf Johann von Habsburg beurkundet, dass Adel...
# ...                                                   ...
# 123359  Propst Wernher von St. Florian verleiht das Ka...
# 123364  Chunrat von Law, Pfarrer zu St. Marienkirchen ...
# 123366  Thomas von Lav und seine Söhne verzichten auf ...
# 123355  Friedrich Zwickel gibt eine Wiese in Lugheim z...
# 219177  Ortlib der Satzer, Bürger zu Straubing, einigt...
#
#        cei_abstract_foreign  \
# 218288                   []
# 168004                   []
# 168953                   []
# 185592                   []
# 184906                   []
# ...                     ...
# 123359                   []
# 123364                   []
# 123366                   []
# 123355                   []
# 219177                   []
#
#                                          cei_tenor_joined cei_pTenor  \
# 218288  Wir Irmegart van Schonecgen, van der genaiden ...         []
# 168004  Ich Eglolff von Roschach herr Eglolfs salgen s...         []
# 168953  Ich Hans von Bodmun ritter gesesen ze Kúnseg v...         []
# 185592  Wir Albr. etc. tun chunt, daz wir vnserm getre...         []
# 184906  Ich graue Johans von Habspurg kúnden allen den...         []
# ...                                                   ...        ...
# 123359  Wjr Wernher von Gotes verhengnu°zze Probst des...         []
# 123364  Ich Chunrat von Law genant Pharrer datz sand M...         []
# 123366  Ich thomas von Lav vnd Elspet mein havsvrov vn...         []
# 123355  Ich fridreich zwikchel vergich vnd tvn chvnt a...         []
# 219177  Ich Ortlib der Sætzer, burger dacz Strawbing, ...         []
#
#         cei_placeName cei_lang_MOM           cei_date  \
# 218288         [Köln]      Deutsch  [1384 Februar 21]
# 168004             []      Deutsch                 []
# 168953             []      Deutsch                 []
# 185592      [Waldsee]      Deutsch                 []
# 184906             []      Deutsch                 []
# ...               ...          ...                ...
# 123359  [St. Florian]      Deutsch                 []
# 123364        [o. O.]      Deutsch                 []
# 123366        [o. O.]      Deutsch                 []
# 123355        [o. O.]      Deutsch                 []
# 219177             []      Deutsch     [1300 Juni 11]
#
#                              cei_dateRange  cei_date_ATTRIBUTE_value  \
# 218288                                  []                13840221.0
# 168004                [11. September 1366]                       NaN
# 168953  [undatiert (um 11. November 1385)]                       NaN
# 185592                 [17. November 1354]                       NaN
# 184906                     [30. März 1339]                       NaN
# ...                                    ...                       ...
# 123359                   [15. August 1327]                       NaN
# 123364                       [4. Mai 1327]                       NaN
# 123366                       [4. Mai 1327]                       NaN
# 123355                      [25. Mai 1326]                       NaN
# 219177                                  []                13000611.0
#
#         cei_dateRange_ATTRIBUTE_from  cei_dateRange_ATTRIBUTE_to  \
# 218288                           NaN                         NaN
# 168004                    13660911.0                  13660911.0
# 168953                    13851111.0                  13851111.0
# 185592                    13541117.0                  13541117.0
# 184906                    13390330.0                  13390330.0
# ...                              ...                         ...
# 123359                    13270815.0                  13270815.0
# 123364                    13270504.0                  13270504.0
# 123366                    13270504.0                  13270504.0
# 123355                    13260525.0                  13260525.0
# 219177                           NaN                         NaN
#
#                            cei_graphic_ATTRIBUTE_url_orig  \
# 218288  [DE_AEK_MiK_AI_135_001.jpg, DE_AEK_MiK_AI_135_...
# 168004  [StiASG_13660911_MM3-A4_v.jpg, StiASG_13660911...
# 168953  [StadtASG_13851111_StadtASG-V-5b_v.jpg, StadtA...
# 185592                                                 []
# 184906                                                 []
# ...                                                   ...
# 123359                                                 []
# 123364  [K.._MOM-Bilddateien._~StFlorianjpgweb._~Urkun...
# 123366  [K.._MOM-Bilddateien._~StFlorianjpgweb._~Urkun...
# 123355  [K.._MOM-Bilddateien._~StFlorianjpgweb._~Urkun...
# 219177  [SpAR-Regensburg_13000611_r.jpg, SpAR-Regensbu...
#
#        cei_graphic_ATTRIBUTE_url_copy  date_joined language_label  \
# 218288                             []     13840221           fnhd
# 168004                             []     13660911           fnhd
# 168953                             []     13851111           fnhd
# 185592                             []     13541117           fnhd
# 184906                             []     13390330           fnhd
# ...                               ...          ...            ...
# 123359                             []     13270815           fnhd
# 123364                             []     13270504           fnhd
# 123366                             []     13270504           fnhd
# 123355                             []     13260525           fnhd
# 219177                             []     13000611           fnhd
#
#         language_score language_langid confidence_langid
# 218288        0.999968              de          0.959485
# 168004        0.999968              de          0.999995
# 168953        0.999968              lb          0.999999
# 185592        0.999967              de               1.0
# 184906        0.999968              de               1.0
# ...                ...             ...               ...
# 123359        0.999967              de               1.0
# 123364        0.999968              de               1.0
# 123366        0.999967              de               1.0
# 123355        0.999964              de               1.0
# 219177        0.999967              de               1.0
#
# [9191 rows x 19 columns]

# %% [markdown]
# Using the implementation's Probability Normalization (see https://github.com/saffsd/langid.py), sorting the charters by confidence_langid suggests that practically all pieces have a score between 0.95 and 1, suggesting a high certainty regarding the classification.

# %% [markdown]
# For these reasons, no further filtering is done. Further narrowing down the corpus by addition manual restrictions would not be helpful, as it might count as some form of manipulation.
# Given that some Latin will always be included in the charters given the developments of charter language in mhg, this suffices.

# %% [markdown]
# # Finalize and export

# %%
final_language_filtered["year"] = final_language_filtered["date_joined"].apply(
    lambda date: int(str(int(round(date)))[:4])
)

# %%
final_language_filtered.to_json("../data-push/0b-preprocessing-main/charters-filtered-final.json")
